# %% [markdown]
# ### Connect to Duckdb and Inspect Database Schema

# %%
import duckdb

with duckdb.connect("data/sakila.duckdb") as conn:
    desc = conn.sql("DESC;").df()
desc
# Out:
#    database   schema                 name  \
# 0    sakila  staging           _dlt_loads
# 1    sakila  staging  _dlt_pipeline_state
# 2    sakila  staging         _dlt_version
# 3    sakila  staging                actor
# 4    sakila  staging              address
# 5    sakila  staging             category
# 6    sakila  staging                 city
# 7    sakila  staging              country
# 8    sakila  staging             customer
# 9    sakila  staging                 film
# 10   sakila  staging           film_actor
# 11   sakila  staging        film_category
# 12   sakila  staging            inventory
# 13   sakila  staging             language
# 14   sakila  staging              payment
# 15   sakila  staging               rental
# 16   sakila  staging                staff
# 17   sakila  staging                store
#
#                                          column_names  \
# 0   [load_id, schema_name, status, inserted_at, sc...
# 1   [version, engine_version, pipeline_name, state...
# 2   [version, engine_version, inserted_at, schema_...
# 3   [actor_id, first_name, last_name, last_update,...
# 4   [address_id, address, address2, district, city...
# 5   [category_id, name, last_update, _dlt_load_id,...
# 6   [city_id, city, country_id, last_update, _dlt_...
# 7   [country_id, country, last_update, _dlt_load_i...
# 8   [customer_id, store_id, first_name, last_name,...
# 9   [film_id, title, description, release_year, la...
# 10  [actor_id, film_id, last_update, _dlt_load_id,...
# 11  [film_id, category_id, last_update, _dlt_load_...
# 12  [inventory_id, film_id, store_id, last_update,...
# 13  [language_id, name, last_update, _dlt_load_id,...
# 14  [payment_id, customer_id, staff_id, rental_id,...
# 15  [rental_id, rental_date, inventory_id, custome...
# 16  [staff_id, first_name, last_name, address_id, ...
# 17  [store_id, manager_staff_id, address_id, last_...
#
#                                          column_types  temporary
# 0   [VARCHAR, VARCHAR, BIGINT, TIMESTAMP WITH TIME...      False
# 1   [BIGINT, BIGINT, VARCHAR, VARCHAR, TIMESTAMP W...      False
# 2   [BIGINT, BIGINT, TIMESTAMP WITH TIME ZONE, VAR...      False
# 3   [DECIMAL(38,9), VARCHAR, VARCHAR, TIMESTAMP, V...      False
# 4   [BIGINT, VARCHAR, VARCHAR, VARCHAR, BIGINT, VA...      False
# 5      [BIGINT, VARCHAR, TIMESTAMP, VARCHAR, VARCHAR]      False
# 6   [BIGINT, VARCHAR, BIGINT, TIMESTAMP, VARCHAR, ...      False
# 7      [BIGINT, VARCHAR, TIMESTAMP, VARCHAR, VARCHAR]      False
# 8   [BIGINT, BIGINT, VARCHAR, VARCHAR, VARCHAR, BI...      False
# 9   [BIGINT, VARCHAR, VARCHAR, VARCHAR, BIGINT, BI...      False
# 10      [BIGINT, BIGINT, TIMESTAMP, VARCHAR, VARCHAR]      False
# 11      [BIGINT, BIGINT, TIMESTAMP, VARCHAR, VARCHAR]      False
# 12  [BIGINT, BIGINT, BIGINT, TIMESTAMP, VARCHAR, V...      False
# 13     [BIGINT, VARCHAR, TIMESTAMP, VARCHAR, VARCHAR]      False
# 14  [BIGINT, BIGINT, BIGINT, BIGINT, DECIMAL(5,2),...      False
# 15  [BIGINT, TIMESTAMP, BIGINT, BIGINT, TIMESTAMP,...      False
# 16  [BIGINT, VARCHAR, VARCHAR, BIGINT, BLOB, VARCH...      False
# 17  [BIGINT, BIGINT, BIGINT, TIMESTAMP, VARCHAR, V...      False

# %% [markdown]
# ### Load and Register Tables from Duckdb Staging

# %%
la = {}
with duckdb.connect("data/sakila.duckdb") as conn:
    for name in desc["name"]:
        la[name] = conn.sql(f"FROM staging.{name};").df()
        duckdb.register(name, la[name])

# %% [markdown]
# ### a) Which movies are longer than 3 hours (180 minutes), show the title and its length?

# %%
la['film'].head(3)
# Out:
#    film_id             title  \
# 0        1  ACADEMY DINOSAUR
# 1        2    ACE GOLDFINGER
# 2        3  ADAPTATION HOLES
#
#                                          description release_year  \
# 0  A Epic Drama of a Feminist And a Mad Scientist...         2006
# 1  A Astounding Epistle of a Database Administrat...         2006
# 2  A Astounding Reflection of a Lumberjack And a ...         2006
#
#    language_id  original_language_id  rental_duration  rental_rate  length  \
# 0            1                  <NA>                6         0.99      86
# 1            1                  <NA>                3         4.99      48
# 2            1                  <NA>                7         2.99      50
#
#    replacement_cost rating                  special_features  \
# 0             20.99     PG  Deleted Scenes,Behind the Scenes
# 1             12.99      G           Trailers,Deleted Scenes
# 2             18.99  NC-17           Trailers,Deleted Scenes
#
#           last_update      _dlt_load_id         _dlt_id
# 0 2021-03-06 15:52:00  1765282237.85467  8UeHo0d4NsKrhQ
# 1 2021-03-06 15:52:00  1765282237.85467  U985ypLic88u7A
# 2 2021-03-06 15:52:00  1765282237.85467  qxu5GG1U0R7RUQ

# %%
duckdb.sql("SELECT title, length FROM film WHERE length > 180 ORDER BY length;").df()
# Out:
#                  title  length
# 0       LAWLESS VISION     181
# 1          WILD APOLLO     181
# 2       STAR OPERATION     181
# 3   RUNAWAY TENENBAUMS     181
# 4     ANALYZE HOOSIERS     181
# 5     HAUNTING PIANIST     181
# 6        LOVE SUICIDES     181
# 7      HOTEL HAPPINESS     181
# 8       INTRIGUE WORST     181
# 9        JACKET FRISCO     181
# 10     BAKED CLEOPATRA     182
# 11      SEARCHERS WAIT     182
# 12         SATURN NAME     182
# 13          REDS POCUS     182
# 14       RECORDS ZORRO     182
# 15       MONSOON CAUSE     182
# 16      YOUNG LANGUAGE     183
# 17      FRONTIER CABIN     183
# 18       SCALAWAG DUCK     183
# 19           WIFE TURN     183
# 20       CATCH AMISTAD     183
# 21      KING EVOLUTION     184
# 22    CRYSTAL BREAKING     184
# 23     SMOOCHY CONTROL     184
# 24      SONS INTERVIEW     184
# 25      SORORITY QUEEN     184
# 26   CONSPIRACY SPIRIT     184
# 27      THEORY MERMAID     184
# 28     MOONWALKER FOOL     184
# 29           HOME PITY     185
# 30       CHICAGO NORTH     185
# 31       MUSCLE BRIGHT     185
# 32        POND SEATTLE     185
# 33         GANGS PRIDE     185
# 34      DARN FORRESTER     185
# 35      CONTROL ANTHEM     185
# 36  SOLDIERS EVOLUTION     185
# 37   SWEET BROTHERHOOD     185
# 38        WORST BANGER     185

# %% [markdown]
# ### b) Which movies have the word "love" in its title? Show the following columns title, rating, length, description

# %%
duckdb.sql("SELECT title, rating, length, description FROM film WHERE title ILIKE '%love%' ORDER BY length DESC;").df()
# Out:
#                 title rating  length  \
# 0       LOVE SUICIDES      R     181
# 1       LAWRENCE LOVE  NC-17     175
# 2          IDAHO LOVE  PG-13     172
# 3    LOVERBOY ATTACKS  PG-13     162
# 4         INDIAN LOVE  NC-17     135
# 5      IDENTITY LOVER  PG-13     119
# 6       GRAFFITI LOVE     PG     117
# 7  STRANGELOVE DESIRE  NC-17     103
# 8        LOVER TRUMAN      G      75
# 9       LOVELY JINGLE     PG      65
#
#                                          description
# 0  A Brilliant Panorama of a Hunter And a Explore...
# 1  A Fanciful Yarn of a Database Administrator An...
# 2  A Fast-Paced Drama of a Student And a Crocodil...
# 3  A Boring Story of a Car And a Butler who must ...
# 4  A Insightful Saga of a Mad Scientist And a Mad...
# 5  A Boring Tale of a Composer And a Mad Cow who ...
# 6  A Unbelieveable Epistle of a Sumo Wrestler And...
# 7  A Awe-Inspiring Panorama of a Lumberjack And a...
# 8  A Emotional Yarn of a Robot And a Boy who must...
# 9  A Fanciful Yarn of a Crocodile And a Forensic ...

# %% [markdown]
# ### c) Calculate descriptive statistics on the length column, The Manager wants, shortest, average, median and longest movie length

# %%
duckdb.sql("SELECT MIN(length) AS min_length_minutes, ROUND(AVG(length)) AS avg_length_minutes, MEDIAN(length) AS mean_length_minutes, MAX(length) AS max_length_minutes FROM film; ").df()
# Out:
#    min_length_minutes  avg_length_minutes  mean_length_minutes  \
# 0                  46               115.0                114.0
#
#    max_length_minutes
# 0                 185

# %% [markdown]
#  ### d) The rental rate is the cost to rent a movie and the rental duration is the number of days a customer can keep the movie.
#  ### The Manager wants to know the 10 most expensive movies to rent per day.

# %%
la["film"].head(1)
# Out:
#    film_id             title  \
# 0        1  ACADEMY DINOSAUR
#
#                                          description release_year  \
# 0  A Epic Drama of a Feminist And a Mad Scientist...         2006
#
#    language_id  original_language_id  rental_duration  rental_rate  length  \
# 0            1                  <NA>                6         0.99      86
#
#    replacement_cost rating                  special_features  \
# 0             20.99     PG  Deleted Scenes,Behind the Scenes
#
#           last_update      _dlt_load_id         _dlt_id
# 0 2021-03-06 15:52:00  1765282237.85467  8UeHo0d4NsKrhQ

# %%
duckdb.sql("SELECT title, rental_rate/rental_duration AS rate_per_day FROM film ORDER BY rate_per_day DESC LIMIT 10;").df()
# Out:
#                  title  rate_per_day
# 0      AMERICAN CIRCUS      1.663333
# 1  BACKLASH UNDEFEATED      1.663333
# 2      BILKO ANONYMOUS      1.663333
# 3      BEAST HUNCHBACK      1.663333
# 4    CARIBBEAN LIBERTY      1.663333
# 5          AUTUMN CROW      1.663333
# 6     CASPER DRAGONFLY      1.663333
# 7       ACE GOLDFINGER      1.663333
# 8     BEHAVIOR RUNAWAY      1.663333
# 9    CASUALTIES ENCINO      1.663333

# %% [markdown]
# ### e) Which actors have played in most movies? Show the top 10 actors with the number of movies they have played in.

# %%
duckdb.sql("SELECT  a.first_name || ' ' || a.last_name AS actor_name, COUNT( distinct fa.film_id) AS total_films FROM actor a LEFT JOIN film_actor fa ON a.actor_id = fa.actor_id GROUP BY  actor_name  ORDER BY total_films DESC LIMIT 10;").df()
# Out:
#            actor_name  total_films
# 0         SUSAN DAVIS           54
# 1      GINA DEGENERES           42
# 2         WALTER TORN           41
# 3         MARY KEITEL           40
# 4      MATTHEW CARREY           39
# 5       SANDRA KILMER           37
# 6      SCARLETT DAMON           36
# 7  ANGELA WITHERSPOON           35
# 8         HENRY BERRY           35
# 9       GROUCHO DUNST           35
